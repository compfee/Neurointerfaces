# %%
# 1.	Собрать установку для измерения данных КГП и произвести замеры этой характеристики, передать их на ПК с помощью pySerial

# %%
import matplotlib.pyplot as plt
import pandas as pd

# %%
emgFrame = pd.read_table("EDA1.dat", sep='	', names=["0"], header=None)
emgFrame.reset_index(inplace = True)
emgFrame.head()
# Out:
#    index       0
# 0      0  112.17
# 1      1   95.22
# 2      2   95.22
# 3      3   95.22
# 4      4   95.22

# %%
plt.figure(figsize=(18, 3))
plt.plot(emgFrame['0'])
plt.show()
